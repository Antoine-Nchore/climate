# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("/home/nchore/Downloads/kenya_synoptic_stations_data_sequential.xlsx")

# %%
df
# Out:
#         Station       Date   SST (°C)  Max Temperature (°C)  Rain Gauge (mm)  \
# 0     Station_1 2013-01-31  24.996321             34.260715              107
# 1     Station_1 2013-02-28  22.464669             32.992642              103
# 2     Station_1 2013-03-31  28.659541             23.185087               90
# 3     Station_1 2013-04-30  25.455560             24.368437              103
# 4     Station_1 2013-05-31  25.648560             31.777639               90
# ...         ...        ...        ...                   ...              ...
# 5275  Station_9 2023-08-31  28.966377             27.691248               97
# 5276  Station_9 2023-09-30  28.972415             26.701093               95
# 5277  Station_9 2023-10-31  25.229174             30.179901               98
# 5278  Station_9 2023-11-30  22.874847             25.959369               95
# 5279  Station_9 2023-12-31  22.580598             32.754766               91
#
#       Streamflow Level (m³/s)  Maize Price (KES)
# 0                   31.203728          24.679836
# 1                    4.116899          49.097296
# 2                   60.848449          35.742693
# 3                   58.428930          30.990855
# 4                  118.482914          21.393512
# ...                       ...                ...
# 5275               133.483106          20.382963
# 5276                87.893075          34.889683
# 5277               119.855504          44.224338
# 5278               172.222704          22.350147
# 5279               108.575626          44.986808
#
# [5280 rows x 7 columns]

# %%
df.head(10)
# Out:
#      Station       Date   SST (°C)  Max Temperature (°C)  Rain Gauge (mm)  \
# 0  Station_1 2013-01-31  24.996321             34.260715              107
# 1  Station_1 2013-02-28  22.464669             32.992642              103
# 2  Station_1 2013-03-31  28.659541             23.185087               90
# 3  Station_1 2013-04-30  25.455560             24.368437              103
# 4  Station_1 2013-05-31  25.648560             31.777639               90
# 5  Station_1 2013-06-30  26.860359             22.557862               94
# 6  Station_1 2013-07-31  22.976306             27.427654               92
# 7  Station_1 2013-08-31  26.373682             22.772817              103
# 8  Station_1 2013-09-30  22.361818             24.879955               97
# 9  Station_1 2013-10-31  24.247476             28.140441               87
#
#    Streamflow Level (m³/s)  Maize Price (KES)
# 0                31.203728          24.679836
# 1                 4.116899          49.097296
# 2                60.848449          35.742693
# 3                58.428930          30.990855
# 4               118.482914          21.393512
# 5               136.846605          33.204575
# 6                62.342215          35.602041
# 7                17.698500          25.879486
# 8               165.747502          30.702600
# 9                14.910129          49.606608

# %%
df.shape
# Out:
# (5280, 7)

# %%
df.isnull().sum()
# Out:
# Station                    0
# Date                       0
# SST (°C)                   0
# Max Temperature (°C)       0
# Rain Gauge (mm)            0
# Streamflow Level (m³/s)    0
# Maize Price (KES)          0
# dtype: int64

# %%
df.describe()
# Out:
#                                 Date     SST (°C)  Max Temperature (°C)  \
# count                           5280  5280.000000           5280.000000
# mean   2018-07-15 23:49:05.454545408    26.000854             27.569618
# min              2013-01-31 00:00:00    22.000093             20.000461
# 25%              2015-10-23 06:00:00    24.004463             23.849594
# 50%              2018-07-15 12:00:00    26.025321             27.552491
# 75%              2021-04-07 12:00:00    27.927655             31.405157
# max              2023-12-31 00:00:00    29.999399             34.995981
# std                              NaN     2.288059              4.374707
#
#        Rain Gauge (mm)  Streamflow Level (m³/s)  Maize Price (KES)
# count      5280.000000              5280.000000        5280.000000
# mean        100.168371                99.223036          34.951260
# min          65.000000                 0.026939          20.005846
# 25%          93.000000                50.361628          27.436463
# 50%         100.000000                99.226507          34.958709
# 75%         107.000000               147.922995          42.320899
# max         135.000000               199.939122          49.997029
# std           9.943078                57.174331           8.636505

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5280 entries, 0 to 5279
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Station                  5280 non-null   object
#  1   Date                     5280 non-null   datetime64[ns]
#  2   SST (°C)                 5280 non-null   float64
#  3   Max Temperature (°C)     5280 non-null   float64
#  4   Rain Gauge (mm)          5280 non-null   int64
#  5   Streamflow Level (m³/s)  5280 non-null   float64
#  6   Maize Price (KES)        5280 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 288.9+ KB

# %%
df.drop(columns=['Station', 'Date', 'Rain Gauge (mm)'], axis = 1, inplace= True)

# %%
df.columns
# Out:
# Index(['Station', 'Date', 'SST (°C)', 'Max Temperature (°C)',
#        'Rain Gauge (mm)', 'Streamflow Level (m³/s)', 'Maize Price (KES)'],
#       dtype='object')

# %%
df
# Out:
#        SST (°C)  Max Temperature (°C)  Streamflow Level (m³/s)  \
# 0     24.996321             34.260715                31.203728
# 1     22.464669             32.992642                 4.116899
# 2     28.659541             23.185087                60.848449
# 3     25.455560             24.368437                58.428930
# 4     25.648560             31.777639               118.482914
# ...         ...                   ...                      ...
# 5275  28.966377             27.691248               133.483106
# 5276  28.972415             26.701093                87.893075
# 5277  25.229174             30.179901               119.855504
# 5278  22.874847             25.959369               172.222704
# 5279  22.580598             32.754766               108.575626
#
#       Maize Price (KES)
# 0             24.679836
# 1             49.097296
# 2             35.742693
# 3             30.990855
# 4             21.393512
# ...                 ...
# 5275          20.382963
# 5276          34.889683
# 5277          44.224338
# 5278          22.350147
# 5279          44.986808
#
# [5280 rows x 4 columns]

# %%
correlation = df.corr()

# %%
plt.figure(figsize=(4,4))

# %%
sns.heatmap(correlation, cbar=True, square=True, fmt='.1f',annot=True, annot_kws={'size': 8}, cmap='Blues')
# Out:
# <Axes: >
